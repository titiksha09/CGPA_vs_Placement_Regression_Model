# %% [markdown]
# <a href="https://colab.research.google.com/github/titiksha09/CGPA_vs_Placement_Regression_Model/blob/main/CGPA_vs_Placement_Regression_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv('placement.csv')
x = ds.iloc[:,:-1]
y = ds.iloc[:,-1]
print(x)
print(y)
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regressor = LinearRegression()
regressor.fit(x_train, y_train)

y_pred = regressor.predict(x_test)

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regressor.predict(x_train), color='blue')
plt.title('CGPA_vs_Placement (Training set)')
plt.xlabel('CGPA')
plt.ylabel('Placement')
plt.show()

# %%
plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regressor.predict(x_train), color='blue')
plt.title('CGPA_vs_Placement (Test set)')
plt.xlabel('CGPA')
plt.ylabel('Placement')
plt.show()

# %%
y_pred = regressor.predict([[8.5]])
print(y_pred)
# Out:
# [3.86920152]
